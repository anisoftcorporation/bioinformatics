# %%
from collections import *

# %%
input_file = "inputs/random.txt"
word_count = defaultdict(int)
linecount = 0
max_count = 0
max_words = list()
with open (input_file,'r') as file:
    for line in file:
        words = line.split()
        for word in words:
            word_count[word.lower()]+=1
                     
        linecount = linecount + 1
#print(word_count)

for word in word_count:
    
    count = word_count[word]
    if count > max_count:
        max_count = count
counts = [value for key, value in word_count.items()]
counts.sort(reverse=True)
print(counts)
for count in counts:
    word = [key for key, value in word_count.items() if value == count]
    print(word+":",word_count[word],":",count)
# Out:
#   File "/var/folders/4s/5d3bkk8j56g7l14h43_qmlt40000gn/T/ipykernel_39526/322003194.py", line 23
#     max_test = [key,value for key, value in word_count.items() if value == max_count]
#                           ^
# SyntaxError: invalid syntax

# %%
+
